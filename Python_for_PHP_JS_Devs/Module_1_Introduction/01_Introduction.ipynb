# %% [markdown]
# 👋 **Привет! Добро пожаловать в Python 3 для PHP и JS-разработчиков!** 🚀
#
# В этом модуле мы сделаем первые шаги в мир Python. Не переживай, если ты уже знаком с PHP или JavaScript, многие концепции будут тебе знакомы. Мы покажем, что общего, и на что стоит обратить внимание.
#
# **Цель этого модуля:**
# - Понять философию Python.
# - Установить Python и настроить виртуальное окружение.
# - Написать свой первый Python-скрипт.
# - Узнать о ключевых отличиях синтаксиса (особенно про отступы!).
#
# Погнали! 👇

# %% [markdown]
# ### 🧠 **1. Философия Python: "Дзен Питона"**
#
# Python — это не просто язык, это целая философия! Чтобы понять его дух, достаточно прочитать "Дзен Питона".
#
# В PHP или JS ты бы, возможно, написал `echo 'Hello';` или `console.log('Hello');`. В Python есть своя команда для этого. Но сначала, давай посмотрим на "Дзен"!

# %%
import this

# %% [markdown]
# ### 🛠️ **2. Установка и окружение: `pip` и `venv`**
#
# Как и в PHP есть `Composer` с `vendor`, а в JS — `npm` с `node_modules`, в Python есть `pip` для пакетов и `venv` для изоляции проектов.
#
# **Что такое `venv`?**
# Это виртуальное окружение. Оно создает изолированную папку для твоего проекта, где будут храниться все его зависимости. Это значит, что разные проекты могут использовать разные версии библиотек, не конфликтуя друг с другом. Очень похоже на `node_modules` в JS, только активируется по-другому.
#
# **Как создать и активировать `venv`?**
#
# 1. **Создать:** `python3 -m venv .venv` (создаст папку `.venv`)
# 2. **Активировать:**
#    - Linux/macOS: `source .venv/bin/activate`
#    - Windows (cmd): `.venv\Scripts\activate.bat`
#    - Windows (PowerShell): `.venv\Scripts\Activate.ps1`
#
# После активации в терминале появится `(.venv)` перед командной строкой. Это значит, что ты внутри виртуального окружения.
#
# **`pip` — менеджер пакетов**
# Как `npm` или `Composer`. Используется для установки библиотек:
# `pip install requests`
#
# **⌨️ Твоя очередь!**
# Открой терминал (если ты в VS Code, то `Ctrl+`\`~` или `Cmd+`\`~`).
# 1. Создай виртуальное окружение: `python3 -m venv .venv`
# 2. Активируй его (выбери команду для своей ОС).
# 3. Установи какую-нибудь библиотеку, например `requests`: `pip install requests`
#
# После этого можешь вернуться сюда. 👇

# %% [markdown]
# ### 🚀 **3. Первый скрипт: "Hello, World!"**
#
# В Python для вывода текста используется функция `print()`.
#
# Вспомни, как ты делал это в других языках:
#
# ```javascript
# console.log("Hello, JavaScript!");
# ```
#
# ```php
# <?php
# echo "Hello, PHP!";
# ```
#
# А теперь в Python. **ЗАДАНИЕ:** Запусти ячейку ниже. 👇

# %%
print("Hello, Python!")

# %% [markdown]
# ### 💡 **4. Ключевое отличие: Отступы вместо скобок!**
#
# Это, пожалуй, самое важное, что нужно запомнить сразу! В PHP и JS блоки кода (например, внутри `if`, `for`, `function`) определяются фигурными скобками `{}`.
#
# ```javascript
# if (true) {
#     // этот код внутри if
# }
# ```
#
# ```php
# if (true) {
#     // этот код внутри if
# }
# ```
#
# В Python нет `{}`. Вместо них используются **отступы** (обычно 4 пробела или 1 таб). Это делает код очень читабельным, но требует внимательности!
#
# **ЗАДАНИЕ:** Попробуй изменить значение `age` и запустить ячейку. Обрати внимание на отступы! 👇

# %%
age = 20

if age >= 18:
    print("Ты совершеннолетний! 🎉")
    print("Добро пожаловать во взрослый мир.")
else:
    print("Ты еще молод. 👶")
print("Это сообщение всегда будет выведено.") # Этот print не имеет отступа, значит он вне if/else

# %% [markdown]
# ### 🚧 **5. Осторожно, грабли! Типичные ошибки с отступами**
#
# Самая частая ошибка новичков в Python — это проблемы с отступами. Python очень строг к ним!
#
# **Ошибка №1: Неправильный отступ**
# Если ты используешь разное количество пробелов или смешиваешь пробелы с табами, Python выдаст ошибку `IndentationError`.
#
# ```python
# # ❌ ЭТО ВЫЗОВЕТ ОШИБКУ!
# if True:
#  print("Один пробел") # Здесь 1 пробел
#     print("Четыре пробела") # А здесь 4 пробела
# ```
#
# **Правило:** Всегда используй одинаковое количество пробелов (обычно 4) для одного уровня отступа. Большинство редакторов кода (как VS Code) автоматически это делают.
#
# **Ошибка №2: Отсутствие отступа, где он нужен**
# После двоеточия `:` всегда ожидается новый блок кода с отступом.
#
# ```python
# # ❌ ЭТО ВЫЗОВЕТ ОШИБКУ!
# if True:
# print("Я должен быть с отступом!")
# ```
#
# **ЗАДАНИЕ:** Попробуй исправить ошибку в ячейке ниже, добавив правильный отступ. 👇

# %%
is_python_fun = True

if is_python_fun:
print("Python это весело! 🎉") # Добавь 4 пробела перед print

# %% [markdown]
# ### ✅ **6. Проверь себя! (Обязательная задача)**
#
# **Задача:** Создай переменную `name` со своим именем и переменную `language` со значением `Python`. Затем используй функцию `print()` для вывода сообщения: `Привет, [ТВОЕ ИМЯ]! Ты изучаешь [ЯЗЫК]!`
#
# **Пример ожидаемого вывода:** `Привет, Алина! Ты изучаешь Python!`
#
# ```python
# # Твой код здесь
#
# ```

# %% [markdown]
# ### 🚀 **7. Дополнительная задача (с уловкой!)**
#
# **Задача:** Создай две переменные: `num1 = 10` и `num2 = 5`. Напиши `if/else` условие, которое проверяет, является ли `num1` больше `num2`. Если да, выведи `num1 больше`. Иначе выведи `num2 больше или равен num1`.
#
# **Уловка:** Что произойдет, если ты случайно поставишь лишний отступ перед `else`? Попробуй это сделать и посмотри на ошибку. Как Python тебе подскажет, что что-то не так?
#
# ```python
# # Твой код здесь
#
# ```

# %% [markdown]
# ---
# 🎉 **Поздравляем! Ты прошел первый модуль!** 🎉
#
# Теперь ты знаешь основы Python, как работать с окружением и самое главное — как правильно использовать отступы. В следующем модуле мы погрузимся в основные типы данных. До встречи! 👋
